# %% [markdown]
# # Assignment1: Implementation of the Izhikevich model
# The assignment consists of the following points:
# 1) Implement the Izhikevich’s model in Matlab
# 2) Develop all the 20 neuro-computational features of biological neurons using the model developed at point 1) and plot o the resulting membrane potential’s time courses into individual figures (one figure for each neuro-computational feature) o the phase portraits that correspond to each of the neuro-computational features (one figure for each neuro-computational feature)

# %% [markdown]
# ## Libraries

# %%
import json

# To work with Google colab
#!wget https://raw.githubusercontent.com/jacons/Computational-NeuroScience-Lab/master/LAB1/Assignment1/Izhikevich.py

from LAB1.Assignment1.Izhikevich import Izhikevich_simulation, Accommodation

# %%
# To work with Google colab
#!wget https://raw.githubusercontent.com/jacons/Computational-NeuroScience-Lab/master/LAB1/Assignment1/configurations.json

with open("./configurations.json") as f:
    izhikevich_parameters = json.load(f)

# %% [markdown]
# ### Tonic spiking (A)

# %%
Izhikevich_simulation(izhikevich_parameters["A"]).simulation().show_charts()

# %% [markdown]
# ### Phasic spiking (B)

# %%
Izhikevich_simulation(izhikevich_parameters["B"]).simulation().show_charts()

# %% [markdown]
# ### Tonic bursting (C)

# %%
Izhikevich_simulation(izhikevich_parameters["C"]).simulation().show_charts()

# %% [markdown]
# ### Phasic bursting (D)

# %%
Izhikevich_simulation(izhikevich_parameters["D"]).simulation().show_charts()

# %% [markdown]
# ### Mixed mode (E)

# %%
Izhikevich_simulation(izhikevich_parameters["E"]).simulation().show_charts()

# %% [markdown]
# ### Spike frequency adaptation (F)

# %%
Izhikevich_simulation(izhikevich_parameters["F"]).simulation().show_charts()

# %% [markdown]
# ### Class 1 excitable (G)

# %%
Izhikevich_simulation(izhikevich_parameters["G"]).simulation().show_charts()

# %% [markdown]
# ### Class 2 excitable (H)

# %%
Izhikevich_simulation(izhikevich_parameters["H"]).simulation().show_charts()

# %% [markdown]
# ### Spike latency (I)

# %%
Izhikevich_simulation(izhikevich_parameters["I"]).simulation().show_charts()

# %% [markdown]
# ### Subthreshold oscillator (J)

# %%
Izhikevich_simulation(izhikevich_parameters["J"]).simulation().show_charts()

# %% [markdown]
# ### Resonator (K)

# %%
Izhikevich_simulation(izhikevich_parameters["K"]).simulation().show_charts()

# %% [markdown]
# ### Integrator (L)

# %%
Izhikevich_simulation(izhikevich_parameters["L"]).simulation().show_charts()

# %% [markdown]
# ### Rebound spike (M)

# %%
Izhikevich_simulation(izhikevich_parameters["M"]).simulation().show_charts()

# %% [markdown]
# ### Rebound burst (N)

# %%
Izhikevich_simulation(izhikevich_parameters["N"]).simulation().show_charts()

# %% [markdown]
# ### Threshold variability (O)

# %%
Izhikevich_simulation(izhikevich_parameters["O"]).simulation().show_charts()

# %% [markdown]
# ### Bistability (P)

# %%
Izhikevich_simulation(izhikevich_parameters["P"]).simulation().show_charts()

# %% [markdown]
# ### DAP (Q)

# %%
Izhikevich_simulation(izhikevich_parameters["Q"]).simulation().show_charts()

# %% [markdown]
# ### Accommodation (R)

# %%
Accommodation(izhikevich_parameters["R"]).simulation().show_charts()

# %% [markdown]
# ### Inhibition induced spiking (S)

# %%
Izhikevich_simulation(izhikevich_parameters["S"]).simulation().show_charts()

# %% [markdown]
# ### Inhibition induced bursting (T)

# %%
Izhikevich_simulation(izhikevich_parameters["T"]).simulation().show_charts()
